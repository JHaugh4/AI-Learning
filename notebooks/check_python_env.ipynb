# %%
import torch

print("torch:", torch.__version__)
# If you're on Linux/Windows with an nvidia GPU this prints true if cuda acceleratin is working.
print("CUDA available (Linux/Windows NVIDIA):", torch.cuda.is_available())
# If you're on a Mac this prints true if Metal GPU is working with pytorch via MPS.
print("MPS available (Apple Silicon):", torch.backends.mps.is_available())
# Out:
# torch: 2.12.0
# CUDA available (Linux/Windows NVIDIA): False
# MPS available (Apple Silicon): True
